# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
with open("../mnist/outimages.npy", "rb") as fp:
    image = np.load(fp)
plt.imshow(image.squeeze(), cmap='gray', vmin=0, vmax=255)

# %%
with open("relevence_scores.npy", "rb") as fp:
    scores = np.load(fp)
scores.shape
# Out:
# (10, 1, 28, 28, 1)

# %%
for i in [6,8]:
    r = scores[i, 0, :, :, 0]
    print(np.min(r), np.max(r))
    plt.imshow(r, cmap='gray', vmin=0, vmax=0.015)
    plt.show()
# Out:
# 0.0 0.013357935
# 0.0 0.013639179

# %%
r6 = scores[6, 0, :, :, 0]
r8 = scores[8, 0, :, :, 0]
plt.imshow(r6-r8, cmap='gray')
